# %%
import pandas as pd

# %%
import numpy as np

# %%
o = pd.read_csv('Orders.csv')

# %%
df = pd.DataFrame(o)

# %%
list(df)
# Out:
# ['Row.ID',
#  'Order.ID',
#  'Order.Date',
#  'Ship.Date',
#  'Ship.Mode',
#  'Customer.ID',
#  'Customer.Name',
#  'Segment',
#  'Postal.Code',
#  'City',
#  'State',
#  'Country',
#  'Region',
#  'Market',
#  'Product.ID',
#  'Category',
#  'Sub.Category',
#  'Product.Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit',
#  'Shipping.Cost',
#  'Order.Priority']

# %%
type(df.Profit)
# Out:
# pandas.core.series.Series

# %%
df.Profit.dtypes
# Out:
# dtype('O')

# %%
import re as re

# %%
df["Sales"] = [re.sub("\$|,", "", i) for i in df["Sales"]]

# %%
df["Profit"] = [re.sub("\$|,", "", i) for i in df["Profit"]]

# %%
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns

# %%
df["Profit"] = pd.to_numeric(df["Profit"])

# %%
df["Sales"] = pd.to_numeric(df["Sales"])

# %%
df.plot(x='Sales', y='Profit')

# %%
df.head(5)
# Out:
#    Row.ID                  Order.ID Order.Date Ship.Date     Ship.Mode  \
# 0   40098  CA-2014-AB10015140-41954   11/11/14  11/13/14   First Class
# 1   26341    IN-2014-JR162107-41675     2/5/14    2/7/14  Second Class
# 2   25330    IN-2014-CR127307-41929   10/17/14  10/18/14   First Class
# 3   13524   ES-2014-KM1637548-41667    1/28/14   1/30/14   First Class
# 4   47221   SG-2014-RH9495111-41948    11/5/14   11/6/14      Same Day
#
#     Customer.ID     Customer.Name      Segment  Postal.Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#         ...         Product.ID    Category Sub.Category  \
# ...

# %%
df['Ship.Date'] = pd.to_datetime(df['Ship.Date'])

# %%
df['Order.Date'] = pd.to_datetime(df['Order.Date'])

# %%
df["year"], df["month"] = df['Order.Date'].dt.year, df['Order.Date'].dt.month

# %%
df
# Out:
#        Row.ID                  Order.ID Order.Date  Ship.Date       Ship.Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 5       22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# 6       30570   IN-2012-TS2134092-41219 2012-11-06 2012-11-08     First Class
# 7       31192   IN-2013-MB1808592-41378 2013-04-14 2013-04-18  Standard Class
# 8       40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 9       36258  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
# 10      36259  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
# ...

# %%
salesyearmonth = Orders.groupby(["year", "month"])["Quantity"].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-447170badffc> in <module>()
# ----> 1 salesyearmonth = Orders.groupby(["year", "month"])["Quantity"].sum()
#
# NameError: name 'Orders' is not defined

# %%
salesyearmonth.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5c6470b4778b> in <module>()
# ----> 1 salesyearmonth.head(5)
#
# NameError: name 'salesyearmonth' is not defined

# %%
df.plot(x='Ship.Date', y='Sales')

# %%
df.plot(x='Order.Date', y='Sales')

# %%
df["Product.ID"].unique()
# Out:
# array(['TEC-PH-5816', 'FUR-CH-5379', 'TEC-PH-5356', ..., 'OFF-AP-3370',
#        'TEC-MA-4598', 'TEC-PH-3808'], dtype=object)

# %%
df.plot(x='Order.Date', y='Sales')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-18a0cda8c6d8> in <module>()
# ----> 1 df["Product.ID"].unique.count()
#
# AttributeError: 'function' object has no attribute 'count'

# %%
plt.bar(y_pos, performance, align='center', alpha=0.5)
